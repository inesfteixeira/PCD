# %% [markdown]
# ## LabDS01 ##
#
#
# The following dataset includes information about several countries. This information was collected by the world bank (https://data.worldbank.org/). Data corresponds to 2016.
#
# `
# dataFile="https://raw.githubusercontent.com/masterfloss/data/main/worlddata2016.xlsx"
# df=pd.read_excel(dataFile)
# `

# %% [markdown]
# # 1. Business Understanding
#
# Purpose: Analyse data and extract knowledge
#
# Observation: Country

# %%
import pandas as pd
import numpy as np
dataFile="https://raw.githubusercontent.com/masterfloss/data/main/worlddata2016.xlsx"
df=pd.read_excel(dataFile)

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name                                     Indicator Name  \
# 0           0  Afghanistan  Access to clean fuels and technologies for coo...
# 1           1  Afghanistan            Access to electricity (% of population)
# 2           2  Afghanistan  Access to electricity, rural (% of rural popul...
# 3           3  Afghanistan  Access to electricity, urban (% of urban popul...
# 4           4  Afghanistan  Account ownership at a financial institution o...
#
#        2016
# 0  32.44000
# 1  97.70000
# 2  97.09936
# 3  99.50000
# 4       NaN

# %%
#ver se os valores estao em numerico
df.dtypes
# Out:
# Unnamed: 0          int64
# Country Name       object
# Indicator Name     object
# 2016              float64
# dtype: object

# %% [markdown]
# # 2. Data Undertanding
#
# * Discuss the data and purposes
# * What are the main limitations?

# %%
#tenho que passar os indicadores para colunas
#um dos problemas é que há muitas variáveis, ou buscamos as variaveis todas que serão usadas especificamente ou eliminar variaveis ou analise fatoriais
df1=pd.pivot_table(df, values='2016', index=['Country Name'], columns=['Indicator Name'])
#verify 
df1.head()
# Out:
# Indicator Name  ARI treatment (% of children under 5 taken to a health provider)  \
# Country Name
# Afghanistan                                                   NaN
# Albania                                                       NaN
# Algeria                                                       NaN
# American Samoa                                                NaN
# Andorra                                                       NaN
#
# Indicator Name  Access to clean fuels and technologies for cooking (% of population)  \
# Country Name
# Afghanistan                                                 32.44
# Albania                                                     77.42
# Algeria                                                     92.62
# American Samoa                                                NaN
# Andorra                                                    100.00
#
# Indicator Name  Access to electricity (% of population)  \
# Country Name
# ...

# %%
#1300 variàveis (aconcelho evitar tantas)
df1.shape
# Out:
# (217, 1328)

# %%
df1.index.name='country'

# %% [markdown]
# # 3. Data Preparation
#
# * Converting data to numeric
# * Missing Values Imputation
# * Normalization
# * Variable Dummification
# * Data balancing
# * Pivot date in order to convert the values "Indicator Name" into comuns
# * Remove all columns that have no values, df1[columns].sum()==0
# * Remove all columns that have more than 210 observations, df1[columns].count()<210

# %%
#converter all 0 into nan
df2=df2.replace(0,np.nan)

# %%
#remove all columns that have no values

for column1 in df2:
    if df2[column1].count()<210:
        df2=df2.drop([column1], axis=1)

# %%
df2.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-23bc78ef4ce5> in <module>
# ----> 1 df2.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df2.head()
# Out:
# Indicator Name  Access to electricity (% of population)  \
# country
# Afghanistan                                   97.700000
# Albania                                      100.000000
# Algeria                                       99.990051
# American Samoa                                      NaN
# Andorra                                      100.000000
#
# Indicator Name  Access to electricity, urban (% of urban population)  \
# country
# Afghanistan                                                  99.5
# Albania                                                     100.0
# Algeria                                                     100.0
# American Samoa                                                NaN
# Andorra                                                     100.0
#
# Indicator Name  Adjusted savings: mineral depletion (current US$)  \
# country
# Afghanistan                                          9.110295e+05
# ...

# %%
#remover all row with na
df2=df2.dropna()
df2.shape
# Out:
# (197, 22)

# %%
#create a list with all the names of countries
countriesList=type (list(df2.index))

#standarizaco
from sklearn.preprocessing import StandardScaler
df2=standardScaler().fit_transformation(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-cb7dcd119133> in <module>
#       4 #standarizaco
#       5 from sklearn.preprocessing import StandardScaler
# ----> 6 df2=standardScaler().fit_transformation(df2)
#
# NameError: name 'standardScaler' is not defined

# %%
from sklearn.preprocessing

# %%
colList=[]
for col1is df2:
    colList.append(coll)
colList
# Out:
#   File "<ipython-input-23-977902171874>", line 2
#     for col1is df2:
#                ^
# SyntaxError: invalid syntax
